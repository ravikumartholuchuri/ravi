# %%
a=10
b=20
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %%
a=5
b=2
a%b
# Out:
# 1

# %%
a//b
# Out:
# 2

# %%
a**b
# Out:
# 25

# %%
p=1000
t=12
r=2
si=(p*t*r)/100
si
# Out:
# 240.0

# %%
pi=3.142
r=2
a=pi*r*r
a
# Out:
# 12.568

# %%
height=10
base=10
a=(1/2)*base*height
a
# Out:
# 50.0

# %%
tc=20
tf=tc*(9/5)+32
tf
# Out:
# 68.0

# %%
l=5
b=10
a=l*b
a
# Out:
# 50

# %%
s=5
a=4*s
a
# Out:
# 20

# %%
r=2
pi=3.142
a=2*pi*r
a
# Out:
# 12.568

# %%
a=1
b=2
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# 2
# 1
